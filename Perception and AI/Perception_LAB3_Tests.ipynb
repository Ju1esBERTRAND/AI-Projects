# %% [markdown]
# # TP 3

# %%
# !pip install ultralytics

#import yolov8 libraries
#https://docs.ultralytics.com/

import ultralytics
from ultralytics import YOLO

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# mount google colab
from google.colab import drive
drive.mount('/content/drive')

#on charge notre modèle, entrainé sur notre dataset
#tutorial : https://docs.ultralytics.com/modes/predict/#inference-sources

#model = YOLO('/content/drive/MyDrive/SE-5104A/best.torchscript',task='detect') # your trained model
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 50985, done.
# remote: Counting objects: 100% (1033/1033), done.
# remote: Compressing objects: 100% (384/384), done.
# remote: Total 50985 (delta 920), reused 654 (delta 649), pack-reused 49952 (from 3)
# Receiving objects: 100% (50985/50985), 29.32 MiB | 9.32 MiB/s, done.
# Resolving deltas: 100% (37636/37636), done.

# %%
# TRACKING

results = model.track(
    source="/content/drive/MyDrive/SE-5104A/test_sequence/test_images",
    show=False,
    save=True,
    name='test_result',
    persist=True
  )
# Out:
# image 1/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00001.png: 640x640 2 persons, 285.7ms
# image 2/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00002.png: 640x640 1 person, 302.2ms
# image 3/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00003.png: 640x640 1 person, 302.4ms
# image 4/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00004.png: 640x640 1 person, 309.3ms
# image 5/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00005.png: 640x640 1 person, 309.7ms
# image 6/349 /content/drive/MyDrive/SE-5104A/test_sequence/test_images/PASS-2LBO_X-F3-B0_P848995_20210303145112_275_cs013_00006.png: 640x640 1 person, 306.0ms
# ...

# %%
import cv2
import os

#CONVERT SEQUENCE OF IMAGES TO VIDEO

# Define input/output paths
image_folder = "/content/drive/MyDrive/SE-5104A/test_sequence/test_images"
video_path = "/content/test_video.mp4"
frame_rate = 30  # Frames per second

# Get image files in sorted order
images = [img for img in sorted(os.listdir(image_folder)) if img.endswith(('.jpg', '.png', '.jpeg'))]

# Read the first image to get dimensions
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

# Initialize VideoWriter
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video = cv2.VideoWriter(video_path, fourcc, frame_rate, (width, height))

# Write images to video
for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

video.release()
print(f"Video saved at {video_path}")
# Out:
# Video saved at /content/test_video.mp4

# %%
# COUNTING IN RECTANGLE
# !python ultralytics/examples/YOLOv8-Region-Counter/yolov8_region_counter.py --source "/content/test_video.mp4" --weights '/content/drive/MyDrive/SE-5104A/best.pt' --save-img
# Out:
# 0: 640x640 2 persons, 234.7ms
# Speed: 9.1ms preprocess, 234.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 persons, 224.3ms
# Speed: 4.8ms preprocess, 224.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 216.8ms
# Speed: 5.7ms preprocess, 216.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 208.3ms
# Speed: 6.0ms preprocess, 208.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 221.3ms
# Speed: 5.8ms preprocess, 221.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 persons, 216.1ms
# Speed: 5.9ms preprocess, 216.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 220.6ms
# Speed: 6.2ms preprocess, 220.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 persons, 224.0ms
# ...
